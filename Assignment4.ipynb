# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **economic activity or measures** (see below) for the region of **Ann Arbor, Michigan, United States**, or **United States** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Ann Arbor, Michigan, United States** to Ann Arbor, USA. In that case at least one source file must be about **Ann Arbor, Michigan, United States**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Ann Arbor, Michigan, United States** and **economic activity or measures**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **economic activity or measures**?  For this category you might look at the inputs or outputs to the given economy, or major changes in the economy compared to other regions.
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df_t = pd.read_csv('./data/Assigment4_Datos_Hidrometeorol_gicos_Crudos-Red_de_Estaciones_IDEAM___Temperatura.csv')

# %%
df_t.head()
# Out:
#    CodigoEstacion  CodigoSensor        FechaObservacion  ValorObservado  \
# 0        21205791            68  08/03/2020 05:00:00 PM            16.2
# 1        21205791            68  08/03/2020 06:00:00 PM            15.2
# 2        21205791            68  08/03/2020 07:00:00 PM            14.6
# 3        21205791            68  08/03/2020 01:00:00 AM            13.6
# 4        21205791            68  08/03/2020 10:00:00 PM            13.6
#
#              NombreEstacion Departamento    Municipio ZonaHidrografica  \
# 0  APTO EL DORADO - TX GPRS  BOGOTA D.C.  BOGOTA, D.C   ALTO MAGDALENA
# 1  APTO EL DORADO - TX GPRS  BOGOTA D.C.  BOGOTA, D.C   ALTO MAGDALENA
# 2  APTO EL DORADO - TX GPRS  BOGOTA D.C.  BOGOTA, D.C   ALTO MAGDALENA
# 3  APTO EL DORADO - TX GPRS  BOGOTA D.C.  BOGOTA, D.C   ALTO MAGDALENA
# 4  APTO EL DORADO - TX GPRS  BOGOTA D.C.  BOGOTA, D.C   ALTO MAGDALENA
#
#    Latitud  Longitud DescripcionSensor UnidadMedida
# 0    4.706   -74.151     Temp Aire 2 m           °C
# ...

# %%
data2 = df_t[['FechaObservacion','ValorObservado']]

# %%
data2.head()
# Out:
#          FechaObservacion  ValorObservado
# 0  08/03/2020 05:00:00 PM            16.2
# 1  08/03/2020 06:00:00 PM            15.2
# 2  08/03/2020 07:00:00 PM            14.6
# 3  08/03/2020 01:00:00 AM            13.6
# 4  08/03/2020 10:00:00 PM            13.6

# %%
data2['measure']= pd.to_datetime(data2.loc[:,'FechaObservacion'],format='%m/%d/%Y %I:%M:%S %p')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data2.dtypes
# Out:
# FechaObservacion            object
# ValorObservado             float64
# measure             datetime64[ns]
# dtype: object

# %%
data2.head()
# Out:
#          FechaObservacion  ValorObservado             measure
# 0  08/03/2020 05:00:00 PM            16.2 2020-08-03 17:00:00
# 1  08/03/2020 06:00:00 PM            15.2 2020-08-03 18:00:00
# 2  08/03/2020 07:00:00 PM            14.6 2020-08-03 19:00:00
# 3  08/03/2020 01:00:00 AM            13.6 2020-08-03 01:00:00
# 4  08/03/2020 10:00:00 PM            13.6 2020-08-03 22:00:00

# %%
data2.set_index('measure',inplace=True)
data2.sort_index(inplace=True)
data2.drop(['FechaObservacion'], axis=1, inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
data2.head()
# Out:
#                      ValorObservado
# measure
# 2014-08-29 10:00:00            16.6
# 2014-08-29 11:00:00            17.1
# 2014-08-29 12:00:00            19.3
# 2014-08-29 13:00:00            18.2
# 2014-08-29 14:00:00            18.8

# %%
y2020 = data2[(data2.index.year==2020) & (data2.index.month==8)]
y2019 = data2[(data2.index.year==2019) & (data2.index.month==8)]
y2018 = data2[(data2.index.year==2018) & (data2.index.month==8)]
y2017 = data2[(data2.index.year==2017) & (data2.index.month==8)]

# %%
y2020['metrica'] = y2020.index
y2020['monthDayHour']= y2020['metrica'].dt.strftime('%m/%d %H')

y2019['metrica'] = y2019.index
y2019['monthDayHour']= y2019['metrica'].dt.strftime('%m/%d %H')

y2018['metrica'] = y2018.index
y2018['monthDayHour']= y2018['metrica'].dt.strftime('%m/%d %H')

y2017['metrica'] = y2017.index
y2017['monthDayHour']= y2017['metrica'].dt.strftime('%m/%d %H')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
y2020['monthDayHour']= pd.to_datetime(y2020.loc[:,'monthDayHour'],format='%m/%d %H')
y2019['monthDayHour']= pd.to_datetime(y2019.loc[:,'monthDayHour'],format='%m/%d %H')
y2018['monthDayHour']= pd.to_datetime(y2018.loc[:,'monthDayHour'],format='%m/%d %H')
y2017['monthDayHour']= pd.to_datetime(y2017.loc[:,'monthDayHour'],format='%m/%d %H')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
y2020.set_index('monthDayHour',inplace=True)
y2020.sort_index(inplace=True)
y2020.drop('metrica',axis=1, inplace=True)

y2019.set_index('monthDayHour',inplace=True)
y2019.sort_index(inplace=True)
y2019.drop('metrica',axis=1, inplace=True)

y2018.set_index('monthDayHour',inplace=True)
y2018.sort_index(inplace=True)
y2018.drop('metrica',axis=1, inplace=True)

y2017.set_index('monthDayHour',inplace=True)
y2017.sort_index(inplace=True)
y2017.drop('metrica',axis=1, inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# ...

# %%
y1 = y2020[y2020.index.day < 15 ]
y2 = y2019[y2019.index.day < 15 ]
y3 = y2018[y2018.index.day < 15 ]
y4 = y2017[y2017.index.day < 15 ]

# %%
_,ax = plt.subplots(figsize=(12,6))
ax.plot(y4,c='g')
ax.plot(y3,c='y')
ax.plot(y2,c='b')
ax.plot(y1,'r-d',lw=1.5)
ax.grid(linestyle=':')
ax.set_title('Match current August temperature with August of before years \n in Bogota - Colombia', fontsize=20)
ax.set_ylabel('Celsius degrees  (ºC)')
ax.set_xlabel('Days of August')
ax.set_ylim(6,25)
ax.legend(labels=['2017','2018','2019','2020'], title='Year', ncol=4,loc='upper right')
ax.set_xticks(y2[y2.index.hour == 0 ].index)
ax.set_xticklabels(np.arange(1,15), rotation=0)
ax.text('1900-08-01',3,'Data source: https://www.datos.gov.co/Ambiente-y-Desarrollo-Sostenible/Datos-Hidrometeorol-gicos-Crudos-Red-de-Estaciones/sbwg-7ju4/data',fontsize=8)
ax.text('1900-08-07',2,'Author: Jairo Collante',fontsize=8)
